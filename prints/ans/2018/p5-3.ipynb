# %%
from vpython import *
import math

def spring_mass(m, k, y0, T):
    h = 10
    r = 0.5
    b = sphere()
    s = helix(pos=vector(0,h,0), axis=vector(0,-h,0), radius=r, thickness=r/4.0)
    ceil = box(pos=vector(0,h,0), length=10, height=0.1, width=10)
    
mass_spring()
